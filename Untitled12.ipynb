# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephBenhar/ANN-/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
import datetime as dt
# %matplotlib inline

# %%
# !pip install scikit-mdr scikit-multilearn
# Out:
# Requirement already satisfied: scikit-mdr in /usr/local/lib/python3.10/dist-packages (0.4.5)
# Requirement already satisfied: scikit-multilearn in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scikit-mdr) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scikit-mdr) (1.11.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from scikit-mdr) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from scikit-mdr) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->scikit-mdr) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->scikit-mdr) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->scikit-mdr) (1.16.0)

# %%
# !pip install scikit-mdr
# Out:
# Requirement already satisfied: scikit-mdr in /usr/local/lib/python3.10/dist-packages (0.4.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scikit-mdr) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scikit-mdr) (1.11.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from scikit-mdr) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from scikit-mdr) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit-mdr) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->scikit-mdr) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->scikit-mdr) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->scikit-mdr) (1.16.0)

# %%
# importing necessary Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
#import plotly.offline as pyoff
import plotly.graph_objs as go
#import plotly.figure_factory as ff

# avoid displaying warnings
import warnings
warnings.filterwarnings("ignore")

#import machine learning related libraries
from sklearn.svm import SVC
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, cross_val_score, train_test_split, GridSearchCV, cross_validate
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.cluster import KMeans
import xgboost as xgb
import time
from yellowbrick.cluster import KElbowVisualizer
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/Consumer behaviour.zip",encoding='ISO-8859-1')
df = data.copy()
df.head()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
# Convert 'InvoiceDate' to DateTime format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Find the start and end dates
start_date = df['InvoiceDate'].min()
end_date = df['InvoiceDate'].max()

print("Start Date:", start_date)
print("End Date:", end_date)
# Out:
# Start Date: 2010-12-01 08:26:00
# End Date: 2011-12-09 12:50:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# Check null values
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# drop null values
df.dropna(inplace=True)
df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# check duplicates
df[df.duplicated()].shape
# Out:
# (5225, 8)

# %%
# Drop duplicated data
df = df.drop_duplicates(keep='first')
df.shape
# Out:
# (401604, 8)

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
data = data[~data.InvoiceNo.str.contains('C',na=False)]
print("Dataset is free from cancelled products information")
# Out:
# Dataset is free from cancelled products information

# %%
# Drop data contains "C" in Invoice
df = df[~df['InvoiceNo'].str.contains('C')]
df.shape
# Out:
# (392732, 8)

# %%
# Convert 'Quantity' column to float and assign it back to the DataFrame
df['Quantity'] = df['Quantity'].astype('float')

# Change 'InvoiceDate' dtype to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Checking the datatypes after conversion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392732 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    392732 non-null  object
#  1   StockCode    392732 non-null  object
#  2   Description  392732 non-null  object
#  3   Quantity     392732 non-null  float64
#  4   InvoiceDate  392732 non-null  datetime64[ns]
#  5   UnitPrice    392732 non-null  float64
#  6   CustomerID   392732 non-null  float64
#  7   Country      392732 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 27.0+ MB

# %%
# Create the 'Revenue' column based on the product of 'Quantity' and 'UnitPrice'
df['Revenue'] = df['Quantity'] * df['UnitPrice']

# Display the DataFrame with the newly added 'Revenue' column
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34

# %%
# Checcking the statsitic of numeric features
df[['Quantity', 'UnitPrice', 'Revenue']].describe().T
# Out:
#               count       mean         std  min   25%    50%    75%        max
# Quantity   392732.0  13.153718  181.588420  1.0  2.00   6.00  12.00   80995.00
# UnitPrice  392732.0   3.125596   22.240725  0.0  1.25   1.95   3.75    8142.75
# Revenue    392732.0  22.629195  311.083465  0.0  4.95  12.39  19.80  168469.60

# %%
# checking the price column which has a value of 0
df[df['UnitPrice']==0]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 9302      537197     22841         ROUND CAKE TIN VINTAGE GREEN       1.0
# 33576     539263     22580         ADVENT CALENDAR GINGHAM SACK       4.0
# 40089     539722     22423             REGENCY CAKESTAND 3 TIER      10.0
# 47068     540372     22090              PAPER BUNTING RETROSPOT      24.0
# 47070     540372     22553               PLASTERS IN TIN SKULLS      24.0
# 56674     541109     22168        ORGANISER WOOD ANTIQUE WHITE        1.0
# 86789     543599    84535B         FAIRY CAKES NOTEBOOK A6 SIZE      16.0
# 130188    547417     22062  CERAMIC BOWL WITH LOVE HEART DESIGN      36.0
# 139453    548318     22055   MINI CAKE STAND  HANGING STRAWBERY       5.0
# 145208    548871     22162          HEART GARLAND RUSTIC PADDED       2.0
# 157042    550188     22636   CHILDS BREAKFAST SET CIRCUS PARADE       1.0
# 187613    553000     47566                        PARTY BUNTING       4.0
# 198383    554037     22619            SET OF 6 SOLDIER SKITTLES      80.0
# 279324    561284     22167           OVAL WALL MIRROR DIAMANTE        1.0
# 282912    561669     22960             JAM MAKING SET WITH JARS      11.0
# 285657    561916         M                               Manual       1.0
# 298054    562973     23157           SET OF 6 NATIVITY MAGNETS      240.0
# 314745    564651     23270     SET OF 2 CERAMIC PAINTED HEARTS       96.0
# 314746    564651     23268  SET OF 2 CERAMIC CHRISTMAS REINDEER     192.0
# 314747    564651     22955             36 FOIL STAR CAKE CASES      144.0
# 314748    564651     21786                   POLKADOT RAIN HAT      144.0
# 358655    568158      PADS           PADS TO MATCH ALL CUSHIONS       1.0
# 361825    568384         M                               Manual       1.0
# 379913    569716     22778                   GLASS CLOCHE SMALL       2.0
# 395529    571035         M                               Manual       1.0
# 420404    572893     21208          PASTEL COLOUR HONEYCOMB FAN       5.0
# 436428    574138     23234        BISCUIT TIN VINTAGE CHRISTMAS     216.0
# 436597    574175     22065       CHRISTMAS PUDDING TRINKET POT       12.0
# 436961    574252         M                               Manual       1.0
# 439361    574469     22385            JUMBO BAG SPACEBOY DESIGN      12.0
# 446125    574879     22625                   RED KITCHEN SCALES       2.0
# 446793    574920     22899         CHILDREN'S APRON DOLLY GIRL        1.0
# 446794    574920     23480       MINI LIGHTS WOODLAND MUSHROOMS       1.0
# 454463    575579     22437        SET OF 9 BLACK SKULL BALLOONS      20.0
# 454464    575579     22089        PAPER BUNTING VINTAGE PAISLEY      24.0
# 479079    577129     22464          HANGING METAL HEART LANTERN       4.0
# 479546    577168         M                               Manual       1.0
# 480649    577314     23407       SET OF 2 TRAYS HOME SWEET HOME       2.0
# 485985    577696         M                               Manual       1.0
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS   12540.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 9302   2010-12-05 14:02:00        0.0     12647.0         Germany      0.0
# 33576  2010-12-16 14:36:00        0.0     16560.0  United Kingdom      0.0
# 40089  2010-12-21 13:45:00        0.0     14911.0            EIRE      0.0
# 47068  2011-01-06 16:41:00        0.0     13081.0  United Kingdom      0.0
# 47070  2011-01-06 16:41:00        0.0     13081.0  United Kingdom      0.0
# 56674  2011-01-13 15:10:00        0.0     15107.0  United Kingdom      0.0
# 86789  2011-02-10 13:08:00        0.0     17560.0  United Kingdom      0.0
# 130188 2011-03-23 10:25:00        0.0     13239.0  United Kingdom      0.0
# 139453 2011-03-30 12:45:00        0.0     13113.0  United Kingdom      0.0
# 145208 2011-04-04 14:42:00        0.0     14410.0  United Kingdom      0.0
# 157042 2011-04-14 18:57:00        0.0     12457.0     Switzerland      0.0
# 187613 2011-05-12 15:21:00        0.0     17667.0  United Kingdom      0.0
# 198383 2011-05-20 14:13:00        0.0     12415.0       Australia      0.0
# 279324 2011-07-26 12:24:00        0.0     16818.0  United Kingdom      0.0
# 282912 2011-07-28 17:09:00        0.0     12507.0           Spain      0.0
# 285657 2011-08-01 11:44:00        0.0     15581.0  United Kingdom      0.0
# 298054 2011-08-11 11:42:00        0.0     14911.0            EIRE      0.0
# 314745 2011-08-26 14:19:00        0.0     14646.0     Netherlands      0.0
# 314746 2011-08-26 14:19:00        0.0     14646.0     Netherlands      0.0
# 314747 2011-08-26 14:19:00        0.0     14646.0     Netherlands      0.0
# 314748 2011-08-26 14:19:00        0.0     14646.0     Netherlands      0.0
# 358655 2011-09-25 12:22:00        0.0     16133.0  United Kingdom      0.0
# 361825 2011-09-27 09:46:00        0.0     12748.0  United Kingdom      0.0
# 379913 2011-10-06 08:17:00        0.0     15804.0  United Kingdom      0.0
# 395529 2011-10-13 12:50:00        0.0     12446.0             RSA      0.0
# 420404 2011-10-26 14:36:00        0.0     18059.0  United Kingdom      0.0
# 436428 2011-11-03 11:26:00        0.0     12415.0       Australia      0.0
# 436597 2011-11-03 11:47:00        0.0     14110.0  United Kingdom      0.0
# 436961 2011-11-03 13:24:00        0.0     12437.0          France      0.0
# 439361 2011-11-04 11:55:00        0.0     12431.0       Australia      0.0
# 446125 2011-11-07 13:22:00        0.0     13014.0  United Kingdom      0.0
# 446793 2011-11-07 16:34:00        0.0     13985.0  United Kingdom      0.0
# 446794 2011-11-07 16:34:00        0.0     13985.0  United Kingdom      0.0
# 454463 2011-11-10 11:49:00        0.0     13081.0  United Kingdom      0.0
# 454464 2011-11-10 11:49:00        0.0     13081.0  United Kingdom      0.0
# 479079 2011-11-17 19:52:00        0.0     15602.0  United Kingdom      0.0
# 479546 2011-11-18 10:42:00        0.0     12603.0         Germany      0.0
# 480649 2011-11-18 13:23:00        0.0     12444.0          Norway      0.0
# 485985 2011-11-21 11:57:00        0.0     16406.0  United Kingdom      0.0
# 502122 2011-11-25 15:57:00        0.0     13256.0  United Kingdom      0.0

# %%
# Remove rows that Price have 0 value from the dataset
df = df[df['UnitPrice']>0]
df.shape
# Out:
# (392692, 9)

# %%
# checking total order in dataset
df['InvoiceNo'].nunique()
# Out:
# 18532

# %%
# checking number of customers
df['CustomerID'].nunique()
# Out:
# 4338

# %%
# Checking the number of Quantity sold
df['Quantity'].sum()
# Out:
# 5152002.0

# %%
# 100 Customer with the most Quantity Purchases
plt.style.use('bmh')
df.groupby('CustomerID')['Quantity'].sum().sort_values(ascending=False).head(20).plot(kind='bar', color='blue', figsize=(10,5))
plt.xlabel('CustomerID')
plt.ylabel('Quantity')
plt.title('50 Customer with the most Quantity Purchases', fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %%
# 100 Customer who generate the most Revenue
df.groupby('CustomerID')['Revenue'].sum().sort_values(ascending=False).head(20).plot(kind='bar', color='#4f5dff', figsize=(10,5))
plt.xlabel('CustomerID')
plt.ylabel('Revenue')
plt.title('50 Customer who generate the most Revenue', fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %%
# Revenue per month and year
monthly_revenue = df.groupby([df['InvoiceDate'].dt.year, df['InvoiceDate'].dt.month])['Revenue'].sum()

# Create a line plot of monthly revenue
ax = monthly_revenue.plot(kind='line', figsize=(10,5), color='#6cfff0', linewidth=3)

# Set xticks and xticklabels to show all values
ax.set_xticks(range(len(monthly_revenue.index)))
ax.set_xticklabels(['{}-{}'.format(year, month) for year, month in monthly_revenue.index], rotation=45)

# Set ylabel format
fmt = '{x:,.0f}'
tick = ticker.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

# set title and label
plt.xlabel('Invoice Date')
plt.ylabel('Revenue')
plt.title('Revenue Earned by Month and Year', fontweight='bold')
# Show the plot
plt.show()

# %%
# Checking The Correlation
df[['Quantity','UnitPrice','Revenue']].corr()
# Out:
#            Quantity  UnitPrice   Revenue
# Quantity   1.000000  -0.004578  0.914451
# UnitPrice -0.004578   1.000000  0.081619
# Revenue    0.914451   0.081619  1.000000

# %%
sns.heatmap(df[['Quantity', 'UnitPrice', 'Revenue']].corr(), annot=True, cmap='coolwarm')
plt.title('Quantity vs UnitPrice vs Revenue')
plt.show()

# %%
df1 = df.drop(['StockCode','Description','Country'], axis=1)
df1.head()
# Out:
#   InvoiceNo  Quantity         InvoiceDate  UnitPrice  CustomerID  Revenue
# 0    536365       6.0 2010-12-01 08:26:00       2.55     17850.0    15.30
# 1    536365       6.0 2010-12-01 08:26:00       3.39     17850.0    20.34
# 2    536365       8.0 2010-12-01 08:26:00       2.75     17850.0    22.00
# 3    536365       6.0 2010-12-01 08:26:00       3.39     17850.0    20.34
# 4    536365       6.0 2010-12-01 08:26:00       3.39     17850.0    20.34

# %%
df1['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
max_date = df1['InvoiceDate'].max()
cutoff_timedelta = dt.timedelta(days=90)
cutoff_date = max_date - cutoff_timedelta

# %%
cutoff_date
# Out:
# Timestamp('2011-09-10 12:50:00')

# %%
before_cutoff = df1[df1['InvoiceDate'] <= cutoff_date]
after_cutoff = df1[df1['InvoiceDate'] > cutoff_date]

# %%
targets = after_cutoff.groupby('CustomerID').sum().rename({'Revenue' : 'total_spend_90'}, axis=1).assign(spend_90 = 1)
targets.drop(['Quantity','UnitPrice'], axis=1, inplace=True)
targets.head()
# Out:
#             total_spend_90  spend_90
# CustomerID
# 12347.0            1519.14         1
# 12348.0             310.00         1
# 12349.0            1757.55         1
# 12352.0             944.23         1
# 12356.0              58.35         1

# %%
targets.shape
# Out:
# (2889, 2)

# %%
# create analysis date
analysis_date = df['InvoiceDate'].max() + dt.timedelta(days=1)

# %%
features = before_cutoff.groupby('CustomerID').agg({
    'InvoiceDate': lambda InvoiceDate: (analysis_date - InvoiceDate.max()).days,  # Recency
    'InvoiceNo': lambda InvoiceNo: InvoiceNo.nunique(),  # Frequency (changed to 'InvoiceNo')
    'Revenue': lambda Revenue: Revenue.sum()  # Monetary
})

# %%
features.columns = ['recency', 'frequency', 'monetary']

# %%
features
# Out:
#             recency  frequency  monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12347.0         130          5   2790.86
# 12348.0         249          3   1487.24
# 12350.0         310          1    334.40
# 12352.0         262          5   1561.81
# ...             ...        ...       ...
# 18280.0         278          1    180.60
# 18281.0         181          1     80.82
# 18282.0         126          1    100.21
# 18283.0          96         10   1086.83
# 18287.0         202          1    765.28
#
# [3370 rows x 3 columns]

# %%
# Merge features and targets dataframe
features_df = pd.merge(features, targets, how='left', on='CustomerID').fillna(0)
features_df
# Out:
#             recency  frequency  monetary  total_spend_90  spend_90
# CustomerID
# 12346.0         326          1  77183.60            0.00       0.0
# 12347.0         130          5   2790.86         1519.14       1.0
# 12348.0         249          3   1487.24          310.00       1.0
# 12350.0         310          1    334.40            0.00       0.0
# 12352.0         262          5   1561.81          944.23       1.0
# ...             ...        ...       ...             ...       ...
# 18280.0         278          1    180.60            0.00       0.0
# 18281.0         181          1     80.82            0.00       0.0
# 18282.0         126          1    100.21           77.84       1.0
# 18283.0          96         10   1086.83          958.70       1.0
# 18287.0         202          1    765.28         1072.00       1.0
#
# [3370 rows x 5 columns]

# %%
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.exceptions import NotFittedError
from sklearn.metrics import r2_score, mean_absolute_error

# %%
X = features_df.drop(['total_spend_90','spend_90'], axis=1)
X
# Out:
#             recency  frequency  monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12347.0         130          5   2790.86
# 12348.0         249          3   1487.24
# 12350.0         310          1    334.40
# 12352.0         262          5   1561.81
# ...             ...        ...       ...
# 18280.0         278          1    180.60
# 18281.0         181          1     80.82
# 18282.0         126          1    100.21
# 18283.0          96         10   1086.83
# 18287.0         202          1    765.28
#
# [3370 rows x 3 columns]

# %%
y_spend = features_df[['total_spend_90']]
y_spend = y_spend.to_numpy().reshape(-1)
y_spend
# Out:
# array([   0.  , 1519.14,  310.  , ...,   77.84,  958.7 , 1072.  ])

# %%
pipelines = {
    'rf':make_pipeline(RandomForestRegressor(random_state=42)),
    'gb':make_pipeline(GradientBoostingRegressor(random_state=42))
}

# %%
hypergrid = {
    'rf': {
        'randomforestregressor__min_samples_split': [2, 4, 6],
        'randomforestregressor__min_samples_leaf': [1, 2, 3]
    },
    'gb': {
        'gradientboostingregressor__alpha': [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 0.99]
    }
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = GridSearchCV(pipeline, hypergrid[algo], cv=5, n_jobs=-1)
    try:
        print('Starting training for {}.'.format(algo))
        model.fit(X, y_spend)
        fit_models[algo] = model
        print('{} has been successfully fit.'.format(algo))
    except NotFittedError as e:
        print(repr(e))
# Out:
# Starting training for rf.
# rf has been successfully fit.
# Starting training for gb.
# gb has been successfully fit.

# %%
xgb = XGBRegressor(random_state=42)
params = [    {        'learning_rate': [0.01, 0.1, 0.3, 0.5],
        'max_depth': [3, 5, 7],
        'n_estimators': [50, 100, 150]
    }
]

# GridSearchCV for xgboost
xgb_reg = GridSearchCV(xgb, params, cv=5, n_jobs=-1)

fit_models['xgb_reg'] = xgb_reg.fit(X, y_spend)

# %%
fit_models['xgb_reg'].best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X)
    print('Predicted {}:'.format(algo), yhat)
# Out:
# Predicted rf: [22700.74379008  1600.10033295   461.06712338 ...    95.45704827
#   1016.29419141   951.86472018]
# Predicted gb: [ 880.68081444 1093.04021854  627.48518082 ...  126.48232663  608.50454051
#   385.04510929]
# Predicted xgb_reg: [603.9841  960.49255 696.44617 ... 630.34753 630.34753 630.34753]

# %%
for algo,model in fit_models.items():
    yhat = model.predict(X)
    print('{} scores - R2:{} MAE:{}'.format(algo, r2_score(y_spend, yhat), mean_absolute_error(y_spend, yhat)))
# Out:
# rf scores - R2:0.7968917154756514 MAE:388.4814128355638
# gb scores - R2:0.9673363279269482 MAE:437.3379477149177
# xgb_reg scores - R2:0.4072652707047618 MAE:826.2043207119633

# %%
prediction_reg = fit_models['gb'].predict(X)
prediction_reg
# Out:
# array([ 880.68081444, 1093.04021854,  627.48518082, ...,  126.48232663,
#         608.50454051,  385.04510929])

# %%
pred_reg_df = pd.DataFrame(prediction_reg, columns=['prediction_spend'])
pred_reg_df.head()
# Out:
#    prediction_spend
# 0        880.680814
# 1       1093.040219
# 2        627.485181
# 3        215.185733
# 4        749.430936

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
y_prob = features_df[['spend_90']]
y_prob = y_prob.to_numpy().reshape(-1)
y_prob
# Out:
# array([0., 1., 1., ..., 1., 1., 1.])

# %%
X.head()
# Out:
#             recency  frequency  monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12347.0         130          5   2790.86
# 12348.0         249          3   1487.24
# 12350.0         310          1    334.40
# 12352.0         262          5   1561.81

# %%
# Preparing the pipeline
pipeline_clf = {
   'rfc' : Pipeline([
        ('classifier', RandomForestClassifier(random_state=42))
    ]),

    'gbc' : Pipeline([
        ('classifier', GradientBoostingClassifier(random_state=42))
    ]),

    'xgbc' : Pipeline([
        ('classifier', XGBClassifier(random_state=42))
    ])
}

# %%
# Preparing grid parameters
hyperparams = {
    'rfc' : {
        'classifier__n_estimators': [100, 150, 200],
        'classifier__max_depth': [5, 10, 15],
        'classifier__min_samples_leaf': [1, 2, 3],
        'classifier__min_samples_split': [2, 3, 4]
    },

    'gbc' : {
        'classifier__n_estimators': [100, 150, 200],
        'classifier__max_depth': [5, 10, 15],
        'classifier__min_samples_leaf': [1, 2, 3],
        'classifier__min_samples_split': [2, 3, 4]
    },

    'xgbc' : {
        'classifier__n_estimators': [100, 150, 200],
        'classifier__max_depth': [5, 10, 15],
        'classifier__min_child_weight': [1, 3, 5],
        'classifier__gamma': [0.0, 0.1, 0.2]
    }
}

# %%
fit_clf_models = {}
for algo, pipeline in pipeline_clf.items():
    model = GridSearchCV(pipeline, hyperparams[algo], cv=5, n_jobs=-1)
    try:
        print('Starting training for {}.'.format(algo))
        model.fit(X, y_prob)
        fit_clf_models[algo] = model
        print('{} has been successfully fit.'.format(algo))
    except NotFittedError as e:
        print(repr(e))
# Out:
# Starting training for rfc.
# rfc has been successfully fit.
# Starting training for gbc.
# gbc has been successfully fit.
# Starting training for xgbc.
# xgbc has been successfully fit.

# %%
for algo,model in fit_clf_models.items():
    yhat = model.predict(X)
    print('{} scores - accuracy:{}'.format(algo, accuracy_score(y_prob, yhat)))
# Out:
# rfc scores - accuracy:0.7032640949554896
# gbc scores - accuracy:0.8014836795252226
# xgbc scores - accuracy:0.7593471810089021

# %%
predict_clf = fit_clf_models['xgbc'].predict_proba(X)
predict_clf
# Out:
# array([[0.9059043 , 0.09409568],
#        [0.07085997, 0.92914003],
#        [0.18047005, 0.81952995],
#        ...,
#        [0.39907503, 0.60092497],
#        [0.05177075, 0.94822925],
#        [0.19205731, 0.8079427 ]], dtype=float32)

# %%
# we will take the 2nd column which means probability in class 1 (probability of making a purchase)
predict_clf = predict_clf[:,1]
predict_clf
# Out:
# array([0.09409568, 0.92914003, 0.81952995, ..., 0.60092497, 0.94822925,
#        0.8079427 ], dtype=float32)

# %%
pred_clf_df = pd.DataFrame(predict_clf, columns=['prediction_prob'])
pred_clf_df.head()
# Out:
#    prediction_prob
# 0         0.094096
# 1         0.929140
# 2         0.819530
# 3         0.126804
# 4         0.855161

# %%
# Get GradientBoostingRegressor from fit_models
gb_model = fit_models['gb'].best_estimator_.named_steps['gradientboostingregressor']

# %%
# Get feature importance
feature_importance = gb_model.feature_importances_

# %%
# Create dataframe for show feature importance
df_feature_importance = pd.DataFrame({'Feature': X.columns,
                                      'Importance': feature_importance})

# %%
# Sorting feature importance
df_feature_importance = df_feature_importance.sort_values('Importance', ascending=False)

# %%
# Show feature importance as barplot
plt.bar(df_feature_importance['Feature'], df_feature_importance['Importance'])
plt.xlabel('Feature')
plt.ylabel('Feature Importance')
plt.title('GradientBoostingRegressor - Feature Importance')
plt.xticks(rotation=45)
plt.show()

# %%
# Access the best XGBoost Classifier models from GridSearchCV
best_xgb_model = fit_clf_models['xgbc'].best_estimator_.named_steps['classifier']

# Get feature importance
feature_importance = best_xgb_model.feature_importances_

# %%
# create dataframe for feature and importances
df_feature_importance = pd.DataFrame({'Feature': best_xgb_model.get_booster().feature_names,
                                      'Importance': feature_importance})

# %%
# Sorting feature importance
df_feature_importance = df_feature_importance.sort_values('Importance', ascending=False)

# %%
# plotting feature importances
plt.bar(df_feature_importance['Feature'], df_feature_importance['Importance'])
plt.xlabel('Feature')
plt.ylabel('Feature Importance')
plt.title('XGBoost Classifier - Feature Importance')
plt.xticks(rotation=45)
plt.show()

# %%
features_df
# Out:
#             recency  frequency  monetary  total_spend_90  spend_90
# CustomerID
# 12346.0         326          1  77183.60            0.00       0.0
# 12347.0         130          5   2790.86         1519.14       1.0
# 12348.0         249          3   1487.24          310.00       1.0
# 12350.0         310          1    334.40            0.00       0.0
# 12352.0         262          5   1561.81          944.23       1.0
# ...             ...        ...       ...             ...       ...
# 18280.0         278          1    180.60            0.00       0.0
# 18281.0         181          1     80.82            0.00       0.0
# 18282.0         126          1    100.21           77.84       1.0
# 18283.0          96         10   1086.83          958.70       1.0
# 18287.0         202          1    765.28         1072.00       1.0
#
# [3370 rows x 5 columns]

# %%
prediction_df = pd.concat([pred_reg_df, pred_clf_df, features_df.reset_index()], axis=1)
prediction_df
# Out:
#       prediction_spend  prediction_prob  CustomerID  recency  frequency  \
# 0           880.680814         0.094096     12346.0      326          1
# 1          1093.040219         0.929140     12347.0      130          5
# 2           627.485181         0.819530     12348.0      249          3
# 3           215.185733         0.126804     12350.0      310          1
# 4           749.430936         0.855161     12352.0      262          5
# ...                ...              ...         ...      ...        ...
# 3365        135.869981         0.282309     18280.0      278          1
# 3366        126.482327         0.360957     18281.0      181          1
# 3367        126.482327         0.600925     18282.0      126          1
# 3368        608.504541         0.948229     18283.0       96         10
# 3369        385.045109         0.807943     18287.0      202          1
#
#       monetary  total_spend_90  spend_90
# 0     77183.60            0.00       0.0
# 1      2790.86         1519.14       1.0
# 2      1487.24          310.00       1.0
# 3       334.40            0.00       0.0
# 4      1561.81          944.23       1.0
# ...        ...             ...       ...
# 3365    180.60            0.00       0.0
# 3366     80.82            0.00       0.0
# 3367    100.21           77.84       1.0
# 3368   1086.83          958.70       1.0
# 3369    765.28         1072.00       1.0
#
# [3370 rows x 8 columns]

# %%
# "Identify the top 10 customers with the highest probability of making repeat purchases."
prediction_df.sort_values('prediction_prob', ascending=False).head(10)
# Out:
#       prediction_spend  prediction_prob  CustomerID  recency  frequency  \
# 3183      11872.623970           0.9943     17949.0       93         33
# 2925      30146.601017           0.9943     17511.0       94         21
# 375        2564.562624           0.9943     12971.0       92         64
# 2469       2604.912006           0.9943     16672.0       99         17
# 2862      13102.536922           0.9943     17389.0       96         25
# 586        2928.642369           0.9943     13319.0       92         19
# 2858       7100.296792           0.9943     17381.0       99         24
# 1364       8800.526015           0.9943     14680.0       95         14
# 1138      12133.358434           0.9943     14298.0       99         37
# 46        22954.782425           0.9943     12415.0       99         15
#
#        monetary  total_spend_90  spend_90
# 3183   48209.20        10301.28       1.0
# 2925   59375.75        31686.63       1.0
# 375     8165.32         3024.59       1.0
# 2469    6911.84         1223.10       1.0
# 2862    9504.08        22329.60       1.0
# 586     7390.47         3455.08       1.0
# 2858   18261.65         2013.96       1.0
# 1364   25422.56         3331.55       1.0
# 1138   41182.51        10344.79       1.0
# 46    102087.88        22826.65       1.0

# %%
# 10 customers who have recently made a purchase
recent_purchase = prediction_df[(prediction_df['recency']>90) | (prediction_df['prediction_prob']<0.2)]\
                    .sort_values('recency', ascending=True)
recent_purchase.head(10)
# Out:
#       prediction_spend  prediction_prob  CustomerID  recency  frequency  \
# 1908        122.627661         0.594525     15652.0       91          1
# 1146       1178.994077         0.727062     14312.0       91          5
# 1696       3773.131370         0.978951     15251.0       91          8
# 3267       2243.119947         0.994117     18109.0       91         18
# 254       17893.553534         0.994283     12748.0       91        132
# 59         2976.812152         0.829530     12433.0       91          3
# 2427        122.627661         0.594525     16603.0       91          1
# 1653       5296.205190         0.994283     15189.0       91         33
# 2885       1313.859109         0.790772     17426.0       91          4
# 1185       1048.374671         0.922827     14388.0       91          6
#
#       monetary  total_spend_90  spend_90
# 1908    337.74            0.00       0.0
# 1146   1047.19          564.40       1.0
# 1696   9695.82          789.17       1.0
# 3267   4826.87         3178.05       1.0
# 254   13873.21        19179.98       1.0
# 59     6395.23         6980.64       1.0
# 2427    296.62          185.85       1.0
# 1653  12635.77         3589.62       1.0
# 2885   4280.59          756.67       1.0
# 1185   2277.77          935.07       1.0

# %%
# 10 customers who recently made a purchase but did not repurchase in the next 90 days
recent_purchase[recent_purchase['spend_90'] == 0].head(10)
# Out:
#       prediction_spend  prediction_prob  CustomerID  recency  frequency  \
# 1908        122.627661         0.594525     15652.0       91          1
# 1335        684.804774         0.565139     14628.0       91          2
# 2500        360.190380         0.437321     16723.0       91          2
# 1497        122.627661         0.620675     14915.0       91          2
# 1203        780.934957         0.938136     14414.0       92          7
# 152         268.546300         0.586521     12592.0       92          2
# 876         594.796066         0.592609     13848.0       92          3
# 642         258.585471         0.558568     13441.0       92          1
# 119         385.045109         0.503536     12535.0       92          2
# 1657        154.910488         0.406776     15198.0       92          2
#
#       monetary  total_spend_90  spend_90
# 1908    337.74             0.0       0.0
# 1335    671.96             0.0       0.0
# 2500    576.40             0.0       0.0
# 1497    307.48             0.0       0.0
# 1203   1496.98             0.0       0.0
# 152     437.60             0.0       0.0
# 876    1255.00             0.0       0.0
# 642     296.64             0.0       0.0
# 119     716.35             0.0       0.0
# 1657    193.64             0.0       0.0

# %%
prediction_df[prediction_df['total_spend_90'] == 0].sort_values('prediction_spend', ascending=False).head(10)
# Out:
#       prediction_spend  prediction_prob  CustomerID  recency  frequency  \
# 2202       4187.796022         0.952575     16180.0      100          8
# 408        2615.343456         0.839864     13027.0      114          6
# 1595       2111.210774         0.630456     15098.0      182          3
# 2401       2098.226306         0.659935     16553.0      163         12
# 379        1725.433881         0.622601     12980.0      158          9
# 1964       1724.622007         0.341828     15749.0      235          3
# 213        1610.360070         0.555227     12688.0      114          1
# 849        1544.507045         0.805396     13802.0      139          3
# 1553       1510.558711         0.603465     15032.0      256          3
# 1870       1492.329465         0.787045     15581.0      121         13
#
#       monetary  total_spend_90  spend_90
# 2202  10254.18             0.0       0.0
# 408    6912.00             0.0       0.0
# 1595  39916.50             0.0       0.0
# 2401   5719.82             0.0       0.0
# 379    7374.90             0.0       0.0
# 1964  44534.30             0.0       0.0
# 213    4873.81             0.0       0.0
# 849    4599.42             0.0       0.0
# 1553   4959.10             0.0       0.0
# 1870   3675.77             0.0       0.0
